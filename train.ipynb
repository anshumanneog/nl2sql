# %%
import tensorflow
import keras
import re
import json, pandas as pd
import numpy as np
from lib.query import Query
import torch
from keras.preprocessing.text import one_hot
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch import optim
import numpy as np
from sklearn.metrics.classification import confusion_matrix
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import f1_score, accuracy_score
from keras.preprocessing.text import text_to_word_sequence
from torch.nn.utils.rnn import pad_sequence
import pickle
import os
from nl2sql.model import *
from nl2sql.dataloader import DataTransformer
import nl2sql.eval_utils as eval_utils

os.chdir('/home/project')

# %%
train_sequences, train_columns_sequences, train_target = pickle.load(open('data/train_data_all.pic', 'rb'))
# train_sequences, train_columns_sequences, train_target = train_sequences[:10], train_columns_sequences[:10], train_target[:10]
# pickle.dump([train_sequences, train_columns_sequences, train_target], open('data/train_data.pic', 'wb'))
test_sequences, test_columns_sequences, test_target = pickle.load(open('data/test_data_all.pic', 'rb'))
# pickle.dump([test_sequences, test_columns_sequences, test_target], open('data/test_data.pic', 'wb'))

# train_sequences, train_columns_sequences, train_target = train_sequences[:1000], train_columns_sequences[:1000], train_target[:1000]
# test_sequences, test_columns_sequences, test_target = test_sequences[:1000], test_columns_sequences[:1000], test_target[:1000]

datatransformer = pickle.load(open('data/datatransformer_all.pic', 'rb'))

from torch.utils.data import DataLoader, Dataset

import pprint

pp = pprint.PrettyPrinter(indent=4)


class TrainingDataSet(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, index):
        return self.X[index], self.y[index]


# device = torch.device('cuda: 0')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
embedding_tensors = torch.tensor(datatransformer.embedding_matrix, device=device, dtype=torch.float)
print(embedding_tensors.shape)

train_sequences_tensor = torch.tensor(train_sequences, device=device, dtype=torch.long, requires_grad=False)
test_sequences_tensor = torch.tensor(test_sequences, device=device, dtype=torch.long, requires_grad=False)

test_columns_sequences_tensor = torch.tensor(test_columns_sequences, device=device, dtype=torch.long,
                                             requires_grad=False)
train_columns_sequences_tensor = torch.tensor(train_columns_sequences, device=device, dtype=torch.long,
                                              requires_grad=False)

train_target_tensor = torch.tensor(train_target, device=device, dtype=torch.long, requires_grad=False)
test_target_tensor = torch.tensor(test_target, device=device, dtype=torch.long, requires_grad=False)

train_dataset = TrainingDataSet(list(zip(train_sequences_tensor, train_columns_sequences_tensor)), train_target)
train_dataloader = DataLoader(train_dataset, batch_size=32)

test_dataset = TrainingDataSet(list(zip(test_sequences_tensor, test_columns_sequences_tensor)), test_target)
test_dataloader = DataLoader(test_dataset, batch_size=32)
# embedding_tensors.shape, embedding_matrix.shape
# Out:
# cuda:0
# torch.Size([35322, 300])

# %%
train_columns_sequences.shape
# Out:
# (56364, 73, 5)

# %%
# pickle.dump(datatransformer, open('data/datatransformerlemm.pic', 'wb'))
model = NL2SQL.initialise_encoder_decoder_network(encoder_word_embedding_matrix=embedding_tensors,
                                                  encoder_max_columns_per_table=train_columns_sequences.shape[-2],
                                                  encoder_max_words_per_question=train_sequences.shape[-1],
                                                  encoder_n_lstm_cells=200,
                                                  encoder_bidirectional=True,
                                                  encoder_trainable_embedding=True,
                                                  encoder_n_layers=1,
                                                  decoder_n_lstm_cells=200,
                                                  decoder_n_layers=1,
                                                  decoder_op_seq_len=train_target.shape[-2],
                                                  decoder_action_embedding_dim=16,
                                                  decoder_bidirectional=True,
                                                  decoder_agg_ops=datatransformer.agg,
                                                  decoder_cond_ops=datatransformer.ops,
                                                  decoder_states=datatransformer.states_index)
# Out:
# /home/project/anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py:46: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.4 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# /home/project/anaconda3/lib/python3.6/site-packages/torch/nn/modules/rnn.py:46: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
# model = torch.load('data/training/models/NL2SQL18e:{epoch}.pt'.format(epoch=10))
# optimizer = torch.load('data/training/models/NL2SQL18e:{epoch}_optimizer.pt'.format(epoch=10))

# %%
loss_function = nn.CrossEntropyLoss()

# %%
model.cuda()

# loss_function = nn.CrossEntropyLoss(weight=torch.tensor(agg_weights, device=device, requires_grad=False, dtype=torch.float))
#     weight=torch.tensor([1, 2, 2, 2, 2, 2], dtype=torch.float, device=device,
#                                                         requires_grad=False))

optimizer = optim.Adam(model.parameters(), lr=1e-3)
# model = torch.load("data/training/NL2SQL15e:3.pt")

# %%
for i in range(100):
    model.train()
    loss_value = 0
    for batch_no, (X, y) in enumerate(train_dataloader):
        #         print(y.shape)
        batch_size, op_seq_len, n_actions = y.shape
        y_pred = model(*X, teacher_forcing_ratio=0.2, target_output_seq=torch.tensor(y,
                                                                                     dtype=torch.float,
                                                                                     device=device))
        y = y.view(-1, n_actions)
        # print(y_pred.shape)
        y_pred = y_pred.view(-1, n_actions)

        # _, y_true_label = torch.max(y, 1)
        y_true_label = y.argmax(dim=1)

        loss = loss_function(y_pred, y_true_label.cuda().long())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_value += loss.item()
        print('\r', "Loss: {}, batch: {}".format(loss_value / (batch_no if batch_no > 0 else 1), batch_no), end="")
#         print("Loss: {}, batch: {}".format(loss_value / (batch_no if batch_no > 0 else 1), batch_no), end="\n")
    # optimizer.zero_grad()
    # torch.save(model, 'data/training/NL2SQL15e:{epoch}.pt'.format(epoch=i))
    # model = torch.load("data/training/NL2SQL2e:0.pt")
    with torch.no_grad():
        model.eval()

        train_pred = []
        train_true = []

        test_loss_value = 0
        train_loss_value = 0

        confusion_matrix_test = []
        confusion_matrix_train = []

        for index, (X, y) in enumerate(train_dataloader):
            batch_size, op_seq_len, n_actions = y.shape
            y_pred_train = model(*X)
            y = y.view(-1, n_actions)
            # pickle.dump([y.tolist(), y_pred_train.tolist()], open('data/training/true_pred_ex.pic', 'wb'))
            # sys.exit()
            y_pred_train = y_pred_train.view(-1, n_actions)
            y_pred_train_label = y_pred_train.argmax(dim=1)
            y_true_train_label = y.argmax(dim=1)
            train_loss = loss_function(y_pred_train, y_true_train_label.cuda().long())
            train_loss_value += train_loss.item()
            confusion_matrix_ = confusion_matrix(y_true_train_label.cpu().numpy(),
                                                 y_pred_train_label.cpu().numpy(),
                                                 labels=np.arange(0, n_actions))
            confusion_matrix_train.append(confusion_matrix_)
            train_pred += y_pred_train_label.tolist()
            train_true += y_true_train_label.tolist()
            print('\r', "%d-train-eval" % index, end='')
        try:
            train_loss_value = train_loss_value / index
        except:
            pass
        test_pred = []
        test_true = []
        test_pred_pd = []
        test_true_pd = []
        for index, (X, y) in enumerate(test_dataloader):
            batch_size, op_seq_len, n_actions = y.shape
            y_pred_test = model(*X)
            y = y.view(-1, n_actions)

            y_pred_test = y_pred_test.view(-1, n_actions)

            y_pred_test_label = y_pred_test.argmax(1)
            y_true_test_label = y.argmax(1)

            test_loss = loss_function(y_pred_test, y_true_test_label.cuda().long())
            test_loss_value += test_loss.item()

            confusion_matrix_ = confusion_matrix(y_true_test_label.cpu().numpy(),
                                                 y_pred_test_label.cpu().numpy(),
                                                 labels=np.arange(0, n_actions))

            confusion_matrix_test.append(confusion_matrix_)

            test_pred += y_pred_test_label.tolist()
            test_true += y_true_test_label.tolist()
            print('\r', "%d-test-eval" % index, end='')
        try:
            test_loss_value = test_loss_value / index
        except:
            pass
    print("performance train/test loss: ", train_loss_value, test_loss_value)
    cm_train = np.sum(confusion_matrix_train, axis=0)
    cm_test = np.sum(confusion_matrix_test, axis=0)

    pickle.dump([cm_train, cm_test],
                open('data/training/reports/ConfusionMatrix|e:%d.pic' % i, 'wb'))

    torch.save(model, 'data/training/models/NL2SQL20e:{epoch}.pt'.format(epoch=i))
    torch.save(optimizer, 'data/training/models/NL2SQL20e:{epoch}_optimizer.pt'.format(epoch=i))

    #
    # test_report = eval_utils.get_slotwise_report(cm_test, 26, 44, 6, 4)
    #
    # train_report = eval_utils.get_slotwise_report(cm_train, 26, 44, 6, 4)

    test_report = eval_utils.get_slotwise_report(cm_test, datatransformer.max_words_per_question,
                                                 datatransformer.max_columns_per_table,
                                                 datatransformer.n_agg, datatransformer.n_ops)

    train_report = eval_utils.get_slotwise_report(cm_train, datatransformer.max_words_per_question,
                                                 datatransformer.max_columns_per_table,
                                                 datatransformer.n_agg, datatransformer.n_ops)

    test_report_df = pd.DataFrame.from_dict(test_report, orient='index')
    test_report_df.index = test_report_df.index.map(lambda x: 'testEpoch:%d_' % (i) + x)

    test_report_df.to_csv(open('data/training/reports/NL2SQL20Report.csv', 'a+'))

    train_report_df = pd.DataFrame.from_dict(train_report, orient='index')
    train_report_df.index = train_report_df.index.map(lambda x: 'trainEpoch:%d_' % (i) + x)

    train_report_df.to_csv(open('data/training/reports/NL2SQL20Report.csv', 'a+'))

    performance = {'test_report': test_report,
                   'train_report': train_report}

    pprint.pprint(performance, indent=4)
    # pprint.pprint(performance, open('data/trainAttention.log', 'a+'), indent=4)
# Out:
# /home/project/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if __name__ == '__main__':
#  496-test-evalperformance train/test loss:  0.42142801799942053 0.4837698634834059
# /home/project/nl2sql/nl2sql/eval_utils.py:18: RuntimeWarning: invalid value encountered in true_divide
#   precision = tp / float(tp + fp)
# /home/project/nl2sql/nl2sql/eval_utils.py:17: RuntimeWarning: invalid value encountered in true_divide
#   recall = tp / float(tp + fn)
# /home/project/nl2sql/nl2sql/eval_utils.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = (2 * recall * precision) / (recall + precision)
# {   'test_report': {   'aggop': {   'accuracy': 0.9950443170900023,
#                                     'f1': 0.7009014058018023,
#                                     'precision': 0.718615478265746,
#                                     'recall': 0.741846115098854,
#                                     'total_fn': 4100,
#                                     'total_fp': 4105,
#                                     'total_obs': 15882,
#                                     'total_tn': 1886453,
#                                     'total_tp': 11782},
#                        'condcols': {   'accuracy': 0.9941855980200593,
#                                        'f1': 0.7199517740743593,
#                                        'precision': 0.7257702769810493,
#                                        'recall': 0.7151223976206817,
#                                        'total_fn': 6226,
#                                        'total_fp': 5934,
#                                        'total_obs': 21855,
#                                        'total_tn': 23167231,
#                                        'total_tp': 15629},
#                        'condops': {   'accuracy': 0.9931238970573993,
#                                       'f1': 0.8958579469738362,
#                                       'precision': 0.9025412583368213,
#                                       'recall': 0.8909631663234958,
#                                       'total_fn': 2383,
#                                       'total_fp': 2160,
#                                       'total_obs': 21855,
#                                       'total_tn': 1246945,
#                                       'total_tp': 19472},
#                        'condval': {   'accuracy': 0.9936628757038956,
#                                       'f1': 0.8083837996112818,
#                                       'precision': 0.789795659472865,
#                                       'recall': 0.8286295202594762,
#                                       'total_fn': 7080,
#                                       'total_fp': 9120,
#                                       'total_obs': 41314,
#                                       'total_tn': 8210806,
#                                       'total_tp': 34234},
#                        'end': {   'accuracy': 0.9753981242525336,
#                                   'f1': 0.9787918661909736,
#                                   'precision': 0.9828583882743965,
#                                   'recall': 0.9747588554753992,
#                                   'total_fn': 4671,
#                                   'total_fp': 3146,
#                                   'total_obs': 185055,
#                                   'total_tn': 129539,
#                                   'total_tp': 180384},
#                        'selcol': {   'accuracy': 0.99806488865949,
#                                      'f1': 0.8618302140055564,
#                                      'precision': 0.8621786593031814,
#                                      'recall': 0.8618996663939069,
#                                      'total_fn': 2194,
#                                      'total_fp': 2194,
#                                      'total_obs': 15887,
#                                      'total_tn': 23176939,
#                                      'total_tp': 13693},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9951883513858686,
#                                      'f1': 0.7096856037180903,
#                                      'precision': 0.7218078162452074,
#                                      'recall': 0.7504036622367324,
#                                      'total_fn': 14067,
#                                      'total_fp': 14072,
#                                      'total_obs': 56359,
#                                      'total_tn': 6693249,
#                                      'total_tp': 42292},
#                         'condcols': {   'accuracy': 0.9950532057786985,
#                                         'f1': 0.7562939915784259,
#                                         'precision': 0.7559043352841234,
#                                         'recall': 0.7571216346529751,
#                                         'total_fn': 18638,
#                                         'total_fp': 18824,
#                                         'total_obs': 76738,
#                                         'total_tn': 82195878,
#                                         'total_tp': 58100},
#                         'condops': {   'accuracy': 0.9940558341132586,
#                                        'f1': 0.9084885477865554,
#                                        'precision': 0.9071201093604829,
#                                        'recall': 0.9112564830983346,
#                                        'total_fn': 6810,
#                                        'total_fp': 7285,
#                                        'total_obs': 76738,
#                                        'total_tn': 4425097,
#                                        'total_tp': 69928},
#                         'condval': {   'accuracy': 0.9950343599991637,
#                                        'f1': 0.845122844373666,
#                                        'precision': 0.841538379330692,
#                                        'recall': 0.849186466773659,
#                                        'total_fn': 23117,
#                                        'total_fp': 24672,
#                                        'total_obs': 153282,
#                                        'total_tn': 29131326,
#                                        'total_tp': 130165},
#                         'end': {   'accuracy': 0.9848928394010362,
#                                    'f1': 0.9869064863252357,
#                                    'precision': 0.9885908190519612,
#                                    'recall': 0.9852278832721858,
#                                    'total_fn': 9623,
#                                    'total_fp': 7407,
#                                    'total_obs': 651430,
#                                    'total_tn': 468443,
#                                    'total_tp': 641807},
#                         'selcol': {   'accuracy': 0.9984405199954366,
#                                       'f1': 0.8860621390367687,
#                                       'precision': 0.8860049595086741,
#                                       'recall': 0.8862394436164928,
#                                       'total_fn': 6412,
#                                       'total_fp': 6412,
#                                       'total_obs': 56364,
#                                       'total_tn': 82228664,
#                                       'total_tp': 49952},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.3465179444662486 0.4390713881340719
# {   'test_report': {   'aggop': {   'accuracy': 0.9963138347046739,
#                                     'f1': 0.8290429965802262,
#                                     'precision': 0.8625719799312754,
#                                     'recall': 0.8362296939931998,
#                                     'total_fn': 2601,
#                                     'total_fp': 2606,
#                                     'total_obs': 15882,
#                                     'total_tn': 1887952,
#                                     'total_tp': 13281},
#                        'condcols': {   'accuracy': 0.9951274300162422,
#                                        'f1': 0.7617648779638361,
#                                        'precision': 0.7714887188474019,
#                                        'recall': 0.7524593914436056,
#                                        'total_fn': 5410,
#                                        'total_fp': 4879,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168286,
#                                        'total_tp': 16445},
#                        'condops': {   'accuracy': 0.9942908674808214,
#                                       'f1': 0.9184680682079145,
#                                       'precision': 0.9253763736765702,
#                                       'recall': 0.9117822008693662,
#                                       'total_fn': 1928,
#                                       'total_fp': 1632,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247473,
#                                       'total_tp': 19927},
#                        'condval': {   'accuracy': 0.9948440311581261,
#                                       'f1': 0.8434689497332453,
#                                       'precision': 0.82908422091196,
#                                       'recall': 0.8587645834341869,
#                                       'total_fn': 5835,
#                                       'total_fp': 7301,
#                                       'total_obs': 41314,
#                                       'total_tn': 8212625,
#                                       'total_tp': 35479},
#                        'end': {   'accuracy': 0.9798797759174166,
#                                   'f1': 0.9826968828406016,
#                                   'precision': 0.9843994013534617,
#                                   'recall': 0.9810002431709491,
#                                   'total_fn': 3516,
#                                   'total_fp': 2877,
#                                   'total_obs': 185055,
#                                   'total_tn': 129808,
#                                   'total_tp': 181539},
#                        'selcol': {   'accuracy': 0.9983845787661412,
#                                      'f1': 0.8837302634706771,
#                                      'precision': 0.8841871079935054,
#                                      'recall': 0.8838043683514824,
#                                      'total_fn': 1846,
#                                      'total_fp': 1846,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177287,
#                                      'total_tp': 14041},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9965218131677319,
#                                      'f1': 0.8312629969215811,
#                                      'precision': 0.8671509032739764,
#                                      'recall': 0.8391738675278128,
#                                      'total_fn': 9064,
#                                      'total_fp': 9069,
#                                      'total_obs': 56359,
#                                      'total_tn': 6698252,
#                                      'total_tp': 47295},
#                         'condcols': {   'accuracy': 0.9964608816317916,
#                                         'f1': 0.8235937421186604,
#                                         'precision': 0.8250173081908299,
#                                         'recall': 0.8222914331882509,
#                                         'total_fn': 13637,
#                                         'total_fp': 13451,
#                                         'total_obs': 76738,
#                                         'total_tn': 82201251,
#                                         'total_tp': 63101},
#                         'condops': {   'accuracy': 0.995993477578717,
#                                        'f1': 0.9403907154244437,
#                                        'precision': 0.938259493045032,
#                                        'recall': 0.9425838567593631,
#                                        'total_fn': 4406,
#                                        'total_fp': 4805,
#                                        'total_obs': 76738,
#                                        'total_tn': 4427577,
#                                        'total_tp': 72332},
#                         'condval': {   'accuracy': 0.9968708562977076,
#                                        'f1': 0.8981721362819378,
#                                        'precision': 0.8977892749355167,
#                                        'recall': 0.8986443287535393,
#                                        'total_fn': 15536,
#                                        'total_fp': 15716,
#                                        'total_obs': 153282,
#                                        'total_tn': 29140282,
#                                        'total_tp': 137746},
#                         'end': {   'accuracy': 0.9920773898232914,
#                                    'f1': 0.9931430124525229,
#                                    'precision': 0.9934427689977681,
#                                    'recall': 0.9928434367468493,
#                                    'total_fn': 4662,
#                                    'total_fp': 4269,
#                                    'total_obs': 651430,
#                                    'total_tn': 471581,
#                                    'total_tp': 646768},
#                         'selcol': {   'accuracy': 0.9989442027207892,
#                                       'f1': 0.921182384130644,
#                                       'precision': 0.9211531372473687,
#                                       'recall': 0.9212795401319992,
#                                       'total_fn': 4437,
#                                       'total_fp': 4437,
#                                       'total_obs': 56364,
#                                       'total_tn': 82230639,
#                                       'total_tp': 51927},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.318483008885167 0.4322316515589914
# {   'test_report': {   'aggop': {   'accuracy': 0.9965862242345982,
#                                     'f1': 0.8656529220180226,
#                                     'precision': 0.8809602837257107,
#                                     'recall': 0.8675229819921925,
#                                     'total_fn': 2104,
#                                     'total_fp': 2109,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888449,
#                                     'total_tp': 13778},
#                        'condcols': {   'accuracy': 0.9953408910853863,
#                                        'f1': 0.769558033767818,
#                                        'precision': 0.7882257290228205,
#                                        'recall': 0.7520475863646763,
#                                        'total_fn': 5419,
#                                        'total_fp': 4442,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168723,
#                                        'total_tp': 16436},
#                        'condops': {   'accuracy': 0.9946520109126344,
#                                       'f1': 0.9222783663563505,
#                                       'precision': 0.93834942937458,
#                                       'recall': 0.9068405399222146,
#                                       'total_fn': 2036,
#                                       'total_fp': 1321,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247784,
#                                       'total_tp': 19819},
#                        'condval': {   'accuracy': 0.995173990066158,
#                                       'f1': 0.8527929045004522,
#                                       'precision': 0.8505817273503656,
#                                       'recall': 0.8567071694824999,
#                                       'total_fn': 5920,
#                                       'total_fp': 6212,
#                                       'total_obs': 41314,
#                                       'total_tn': 8213714,
#                                       'total_tp': 35394},
#                        'end': {   'accuracy': 0.9794486057783093,
#                                   'f1': 0.982423084170009,
#                                   'precision': 0.9787348153710009,
#                                   'recall': 0.9861392558968956,
#                                   'total_fn': 2565,
#                                   'total_fp': 3965,
#                                   'total_obs': 185055,
#                                   'total_tn': 128720,
#                                   'total_tp': 182490},
#                        'selcol': {   'accuracy': 0.9985265702826808,
#                                      'f1': 0.8924338747979956,
#                                      'precision': 0.892944863781886,
#                                      'recall': 0.8921759929502109,
#                                      'total_fn': 1713,
#                                      'total_fp': 1713,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177420,
#                                      'total_tp': 14174},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9969511808347752,
#                                      'f1': 0.872238891190673,
#                                      'precision': 0.891362774503769,
#                                      'recall': 0.8737734878191593,
#                                      'total_fn': 7114,
#                                      'total_fp': 7119,
#                                      'total_obs': 56359,
#                                      'total_tn': 6700202,
#                                      'total_tp': 49245},
#                         'condcols': {   'accuracy': 0.997212178507628,
#                                         'f1': 0.858105021706579,
#                                         'precision': 0.8674511371622508,
#                                         'recall': 0.8491229899137325,
#                                         'total_fn': 11578,
#                                         'total_fp': 10040,
#                                         'total_obs': 76738,
#                                         'total_tn': 82204662,
#                                         'total_tp': 65160},
#                         'condops': {   'accuracy': 0.9968447858149788,
#                                        'f1': 0.9498123233520493,
#                                        'precision': 0.9541189740830184,
#                                        'recall': 0.9455810680497276,
#                                        'total_fn': 4176,
#                                        'total_fp': 3510,
#                                        'total_obs': 76738,
#                                        'total_tn': 4428872,
#                                        'total_tp': 72562},
#                         'condval': {   'accuracy': 0.997719477944635,
#                                        'f1': 0.923671194931814,
#                                        'precision': 0.9318881658528585,
#                                        'recall': 0.9160501559217651,
#                                        'total_fn': 12868,
#                                        'total_fp': 10197,
#                                        'total_obs': 153282,
#                                        'total_tn': 29145801,
#                                        'total_tp': 140414},
#                         'end': {   'accuracy': 0.9928065786672344,
#                                    'f1': 0.9937992024378028,
#                                    'precision': 0.9901082575936492,
#                                    'recall': 0.9975177686013846,
#                                    'total_fn': 1617,
#                                    'total_fp': 6492,
#                                    'total_obs': 651430,
#                                    'total_tn': 469358,
#                                    'total_tp': 649813},
#                         'selcol': {   'accuracy': 0.9991510000695975,
#                                       'f1': 0.9358472313087665,
#                                       'precision': 0.9361099771315524,
#                                       'recall': 0.9356681569796323,
#                                       'total_fn': 3626,
#                                       'total_fp': 3626,
#                                       'total_obs': 56364,
#                                       'total_tn': 82231450,
#                                       'total_tp': 52738},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.2953402111301498 0.42070223769593623
# {   'test_report': {   'aggop': {   'accuracy': 0.9964184618802289,
#                                     'f1': 0.8672694356973729,
#                                     'precision': 0.8771449911453502,
#                                     'recall': 0.8723712378793603,
#                                     'total_fn': 2027,
#                                     'total_fp': 2032,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888526,
#                                     'total_tp': 13855},
#                        'condcols': {   'accuracy': 0.9955182571800092,
#                                        'f1': 0.7819081496285296,
#                                        'precision': 0.7863429176573593,
#                                        'recall': 0.7778082818576985,
#                                        'total_fn': 4856,
#                                        'total_fp': 4631,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168534,
#                                        'total_tp': 16999},
#                        'condops': {   'accuracy': 0.9950913048006902,
#                                       'f1': 0.9298208163114007,
#                                       'precision': 0.9341292248975882,
#                                       'recall': 0.9255547929535576,
#                                       'total_fn': 1627,
#                                       'total_fp': 1428,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247677,
#                                       'total_tp': 20228},
#                        'condval': {   'accuracy': 0.995534948027968,
#                                       'f1': 0.862400625041863,
#                                       'precision': 0.8481191250403735,
#                                       'recall': 0.8774023333494699,
#                                       'total_fn': 5065,
#                                       'total_fp': 6488,
#                                       'total_obs': 41314,
#                                       'total_tn': 8213438,
#                                       'total_tp': 36249},
#                        'end': {   'accuracy': 0.9832976647573488,
#                                   'f1': 0.9856222112047595,
#                                   'precision': 0.9882970400312948,
#                                   'recall': 0.9829618221609792,
#                                   'total_fn': 3153,
#                                   'total_fp': 2154,
#                                   'total_obs': 185055,
#                                   'total_tn': 130531,
#                                   'total_tp': 181902},
#                        'selcol': {   'accuracy': 0.9985798221529532,
#                                      'f1': 0.8964847544648803,
#                                      'precision': 0.8971321761386003,
#                                      'recall': 0.8963303329766475,
#                                      'total_fn': 1647,
#                                      'total_fp': 1647,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177486,
#                                      'total_tp': 14240},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9969222903511006,
#                                      'f1': 0.8781072372644387,
#                                      'precision': 0.8907740014701038,
#                                      'recall': 0.8831774871803971,
#                                      'total_fn': 6584,
#                                      'total_fp': 6589,
#                                      'total_obs': 56359,
#                                      'total_tn': 6700732,
#                                      'total_tp': 49775},
#                         'condcols': {   'accuracy': 0.9977924993861966,
#                                         'f1': 0.887674509896378,
#                                         'precision': 0.8856109191298833,
#                                         'recall': 0.8898720321092549,
#                                         'total_fn': 8451,
#                                         'total_fp': 8859,
#                                         'total_obs': 76738,
#                                         'total_tn': 82205843,
#                                         'total_tp': 68287},
#                         'condops': {   'accuracy': 0.997501096773213,
#                                        'f1': 0.9604960015846673,
#                                        'precision': 0.9577012465068067,
#                                        'recall': 0.9633167400766244,
#                                        'total_fn': 2815,
#                                        'total_fp': 3253,
#                                        'total_obs': 76738,
#                                        'total_tn': 4429129,
#                                        'total_tp': 73923},
#                         'condval': {   'accuracy': 0.9983727923715826,
#                                        'f1': 0.9450502411199678,
#                                        'precision': 0.942270410708433,
#                                        'recall': 0.9478803773437194,
#                                        'total_fn': 7989,
#                                        'total_fp': 8917,
#                                        'total_obs': 153282,
#                                        'total_tn': 29147081,
#                                        'total_tp': 145293},
#                         'end': {   'accuracy': 0.9957925271449861,
#                                    'f1': 0.9963545809843324,
#                                    'precision': 0.9977157106464201,
#                                    'recall': 0.9949971600939471,
#                                    'total_fn': 3259,
#                                    'total_fp': 1484,
#                                    'total_obs': 651430,
#                                    'total_tn': 474366,
#                                    'total_tp': 648171},
#                         'selcol': {   'accuracy': 0.9993007634319057,
#                                       'f1': 0.9464389448833574,
#                                       'precision': 0.9467114335750271,
#                                       'recall': 0.9463132495919381,
#                                       'total_fn': 3026,
#                                       'total_fp': 3027,
#                                       'total_obs': 56364,
#                                       'total_tn': 82232049,
#                                       'total_tp': 53338},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.2801319178551317 0.45067865951287167
# {   'test_report': {   'aggop': {   'accuracy': 0.9965184288527715,
#                                     'f1': 0.869952531587363,
#                                     'precision': 0.8789818574162741,
#                                     'recall': 0.8719304873441632,
#                                     'total_fn': 2034,
#                                     'total_fp': 2039,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888519,
#                                     'total_tp': 13848},
#                        'condcols': {   'accuracy': 0.9956386137471089,
#                                        'f1': 0.7855869095799695,
#                                        'precision': 0.8001819754913362,
#                                        'recall': 0.7716769617936399,
#                                        'total_fn': 4990,
#                                        'total_fp': 4222,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168943,
#                                        'total_tp': 16865},
#                        'condops': {   'accuracy': 0.9951115367704222,
#                                       'f1': 0.9295128044334131,
#                                       'precision': 0.945664729815091,
#                                       'recall': 0.914115762983299,
#                                       'total_fn': 1877,
#                                       'total_fp': 1171,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247934,
#                                       'total_tp': 19978},
#                        'condval': {   'accuracy': 0.9955835987959197,
#                                       'f1': 0.8652597527113354,
#                                       'precision': 0.8570179944370062,
#                                       'recall': 0.8746429781672073,
#                                       'total_fn': 5179,
#                                       'total_fp': 6028,
#                                       'total_obs': 41314,
#                                       'total_tn': 8213898,
#                                       'total_tp': 36135},
#                        'end': {   'accuracy': 0.9823125826147164,
#                                   'f1': 0.9848408832208538,
#                                   'precision': 0.9831860361160928,
#                                   'recall': 0.9865013104212261,
#                                   'total_fn': 2498,
#                                   'total_fp': 3122,
#                                   'total_obs': 185055,
#                                   'total_tn': 129563,
#                                   'total_tp': 182557},
#                        'selcol': {   'accuracy': 0.9985861209657562,
#                                      'f1': 0.8978158970408056,
#                                      'precision': 0.8984378013366623,
#                                      'recall': 0.8975892238937496,
#                                      'total_fn': 1627,
#                                      'total_fp': 1627,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177506,
#                                      'total_tp': 14260},
#                        'start': {   'accuracy': 0.9999968527727072,
#                                     'f1': 0.9999685287175452,
#                                     'precision': 0.9999370594159114,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 1,
#                                     'total_obs': 15887,
#                                     'total_tn': 301852,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9972607538588935,
#                                      'f1': 0.8868889549294727,
#                                      'precision': 0.8984622056393047,
#                                      'recall': 0.8888553735871821,
#                                      'total_fn': 6264,
#                                      'total_fp': 6269,
#                                      'total_obs': 56359,
#                                      'total_tn': 6701052,
#                                      'total_tp': 50095},
#                         'condcols': {   'accuracy': 0.9982542916618395,
#                                         'f1': 0.909615377631164,
#                                         'precision': 0.9135103198703712,
#                                         'recall': 0.9058354400688056,
#                                         'total_fn': 7226,
#                                         'total_fp': 6614,
#                                         'total_obs': 76738,
#                                         'total_tn': 82208088,
#                                         'total_tp': 69512},
#                         'condops': {   'accuracy': 0.9978725095588644,
#                                        'f1': 0.9642630419179503,
#                                        'precision': 0.9677698839038653,
#                                        'recall': 0.9609189710443327,
#                                        'total_fn': 2999,
#                                        'total_fp': 2495,
#                                        'total_obs': 76738,
#                                        'total_tn': 4429887,
#                                        'total_tp': 73739},
#                         'condval': {   'accuracy': 0.9988555173756735,
#                                        'f1': 0.959595573739378,
#                                        'precision': 0.9616940088570469,
#                                        'recall': 0.9576205947208414,
#                                        'total_fn': 6496,
#                                        'total_fp': 5824,
#                                        'total_obs': 153282,
#                                        'total_tn': 29150174,
#                                        'total_tp': 146786},
#                         'end': {   'accuracy': 0.9968321978567879,
#                                    'f1': 0.9972628653377268,
#                                    'precision': 0.9958972412008836,
#                                    'recall': 0.9986322398415793,
#                                    'total_fn': 891,
#                                    'total_fp': 2680,
#                                    'total_obs': 651430,
#                                    'total_tn': 473170,
#                                    'total_tp': 650539},
#                         'selcol': {   'accuracy': 0.9994027493141858,
#                                       'f1': 0.9536431803993648,
#                                       'precision': 0.9538618335987555,
#                                       'recall': 0.953516428926265,
#                                       'total_fn': 2620,
#                                       'total_fp': 2619,
#                                       'total_obs': 56364,
#                                       'total_tn': 82232457,
#                                       'total_tp': 53744},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.2686601681830462 0.4505958214041687
# {   'test_report': {   'aggop': {   'accuracy': 0.9965203125917621,
#                                     'f1': 0.8736320855791451,
#                                     'precision': 0.8760832012769526,
#                                     'recall': 0.8785417453721194,
#                                     'total_fn': 1929,
#                                     'total_fp': 1934,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888624,
#                                     'total_tp': 13953},
#                        'condcols': {   'accuracy': 0.9955800483905457,
#                                        'f1': 0.7830444804127203,
#                                        'precision': 0.7931500059083141,
#                                        'recall': 0.7734614504690003,
#                                        'total_fn': 4951,
#                                        'total_fp': 4428,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168737,
#                                        'total_tp': 16904},
#                        'condops': {   'accuracy': 0.9950764185812011,
#                                       'f1': 0.9294056035805964,
#                                       'precision': 0.9396957472323012,
#                                       'recall': 0.9196980096087852,
#                                       'total_fn': 1755,
#                                       'total_fp': 1329,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247776,
#                                       'total_tp': 20100},
#                        'condval': {   'accuracy': 0.9956259061266854,
#                                       'f1': 0.8671713893536214,
#                                       'precision': 0.8561790977250535,
#                                       'recall': 0.8792661083409982,
#                                       'total_fn': 4988,
#                                       'total_fp': 6102,
#                                       'total_obs': 41314,
#                                       'total_tn': 8213824,
#                                       'total_tp': 36326},
#                        'end': {   'accuracy': 0.9831749228929313,
#                                   'f1': 0.9855492423218525,
#                                   'precision': 0.9859863378963822,
#                                   'recall': 0.9851125341114804,
#                                   'total_fn': 2755,
#                                   'total_fp': 2591,
#                                   'total_obs': 185055,
#                                   'total_tn': 130094,
#                                   'total_tp': 182300},
#                        'selcol': {   'accuracy': 0.9986403074755683,
#                                      'f1': 0.901670268694418,
#                                      'precision': 0.9025216043640072,
#                                      'recall': 0.9013029520992006,
#                                      'total_fn': 1568,
#                                      'total_fp': 1567,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177566,
#                                      'total_tp': 14319},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9973964683225957,
#                                      'f1': 0.8989603414636985,
#                                      'precision': 0.9025886291346772,
#                                      'recall': 0.9028549122589116,
#                                      'total_fn': 5475,
#                                      'total_fp': 5480,
#                                      'total_obs': 56359,
#                                      'total_tn': 6701841,
#                                      'total_tp': 50884},
#                         'condcols': {   'accuracy': 0.9985465291724877,
#                                         'f1': 0.9242794268819124,
#                                         'precision': 0.9241796098428477,
#                                         'recall': 0.9244702754828117,
#                                         'total_fn': 5796,
#                                         'total_fp': 5847,
#                                         'total_obs': 76738,
#                                         'total_tn': 82208855,
#                                         'total_tp': 70942},
#                         'condops': {   'accuracy': 0.9981354829255059,
#                                        'f1': 0.9691065605869199,
#                                        'precision': 0.9686211038441707,
#                                        'recall': 0.9697672600276265,
#                                        'total_fn': 2320,
#                                        'total_fp': 2467,
#                                        'total_obs': 76738,
#                                        'total_tn': 4429915,
#                                        'total_tp': 74418},
#                         'condval': {   'accuracy': 0.9991008226994521,
#                                        'f1': 0.9696488844176158,
#                                        'precision': 0.9689541520856626,
#                                        'recall': 0.970387912475046,
#                                        'total_fn': 4539,
#                                        'total_fp': 4758,
#                                        'total_obs': 153282,
#                                        'total_tn': 29151240,
#                                        'total_tp': 148743},
#                         'end': {   'accuracy': 0.9977538854588034,
#                                    'f1': 0.99805596248284,
#                                    'precision': 0.9983748429373255,
#                                    'recall': 0.9977372856638472,
#                                    'total_fn': 1474,
#                                    'total_fp': 1058,
#                                    'total_obs': 651430,
#                                    'total_tn': 474792,
#                                    'total_tp': 649956},
#                         'selcol': {   'accuracy': 0.9994829115038171,
#                                       'f1': 0.9599677653024887,
#                                       'precision': 0.9601183709198008,
#                                       'recall': 0.9599034844936484,
#                                       'total_fn': 2260,
#                                       'total_fp': 2259,
#                                       'total_obs': 56364,
#                                       'total_tn': 82232817,
#                                       'total_tp': 54104},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.2638526804436343 0.4731497816260784
# {   'test_report': {   'aggop': {   'accuracy': 0.9965637757174463,
#                                     'f1': 0.8742002588925759,
#                                     'precision': 0.8788458629730793,
#                                     'recall': 0.8787306384586324,
#                                     'total_fn': 1926,
#                                     'total_fp': 1931,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888627,
#                                     'total_tp': 13956},
#                        'condcols': {   'accuracy': 0.9953635060483573,
#                                        'f1': 0.7729454265189746,
#                                        'precision': 0.783078925574025,
#                                        'recall': 0.7633951040951727,
#                                        'total_fn': 5171,
#                                        'total_fp': 4638,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168527,
#                                        'total_tp': 16684},
#                        'condops': {   'accuracy': 0.9949435642600379,
#                                       'f1': 0.9268669043416123,
#                                       'precision': 0.9383865117813084,
#                                       'recall': 0.9158544955387783,
#                                       'total_fn': 1839,
#                                       'total_fp': 1347,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247758,
#                                       'total_tp': 20016},
#                        'condval': {   'accuracy': 0.9954371507241598,
#                                       'f1': 0.8600917943667777,
#                                       'precision': 0.8488942124916821,
#                                       'recall': 0.8722224911652224,
#                                       'total_fn': 5279,
#                                       'total_fp': 6416,
#                                       'total_obs': 41314,
#                                       'total_tn': 8213510,
#                                       'total_tp': 36035},
#                        'end': {   'accuracy': 0.9828979668911689,
#                                   'f1': 0.9853134341266709,
#                                   'precision': 0.9856117830899251,
#                                   'recall': 0.9850152657318094,
#                                   'total_fn': 2773,
#                                   'total_fp': 2661,
#                                   'total_obs': 185055,
#                                   'total_tn': 130024,
#                                   'total_tp': 182282},
#                        'selcol': {   'accuracy': 0.9986104939005777,
#                                      'f1': 0.9005161631292256,
#                                      'precision': 0.9010976261188071,
#                                      'recall': 0.900358783911374,
#                                      'total_fn': 1583,
#                                      'total_fp': 1583,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177550,
#                                      'total_tp': 14304},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9975294297489045,
#                                      'f1': 0.902407171574243,
#                                      'precision': 0.908483408026649,
#                                      'recall': 0.9058003158324314,
#                                      'total_fn': 5309,
#                                      'total_fp': 5317,
#                                      'total_obs': 56359,
#                                      'total_tn': 6702004,
#                                      'total_tp': 51050},
#                         'condcols': {   'accuracy': 0.9987181215719165,
#                                         'f1': 0.9327502765390691,
#                                         'precision': 0.9335627514002465,
#                                         'recall': 0.9320545231827778,
#                                         'total_fn': 5214,
#                                         'total_fp': 5136,
#                                         'total_obs': 76738,
#                                         'total_tn': 82209566,
#                                         'total_tp': 71524},
#                         'condops': {   'accuracy': 0.998129873772194,
#                                        'f1': 0.9685393912762578,
#                                        'precision': 0.9689972861011291,
#                                        'recall': 0.9681513722015168,
#                                        'total_fn': 2444,
#                                        'total_fp': 2408,
#                                        'total_obs': 76738,
#                                        'total_tn': 4429974,
#                                        'total_tp': 74294},
#                         'condval': {   'accuracy': 0.9992352283483923,
#                                        'f1': 0.9733255570872957,
#                                        'precision': 0.9737422230296008,
#                                        'recall': 0.9729322425333699,
#                                        'total_fn': 4149,
#                                        'total_fp': 4022,
#                                        'total_obs': 153282,
#                                        'total_tn': 29151976,
#                                        'total_tp': 149133},
#                         'end': {   'accuracy': 0.998056383507203,
#                                    'f1': 0.9983186183662741,
#                                    'precision': 0.9981386141652536,
#                                    'recall': 0.9984986875028783,
#                                    'total_fn': 978,
#                                    'total_fp': 1213,
#                                    'total_obs': 651430,
#                                    'total_tn': 474637,
#                                    'total_tp': 650452},
#                         'selcol': {   'accuracy': 0.9995512823263447,
#                                       'f1': 0.9648855195221802,
#                                       'precision': 0.9650247028436245,
#                                       'recall': 0.9648357107373501,
#                                       'total_fn': 1982,
#                                       'total_fp': 1985,
#                                       'total_obs': 56364,
#                                       'total_tn': 82233091,
#                                       'total_tp': 54382},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  496-test-evalperformance train/test loss:  0.2543719668303072 0.4867725732525991
# {   'test_report': {   'aggop': {   'accuracy': 0.996331222927395,
#                                     'f1': 0.8692323714351723,
#                                     'precision': 0.8703119014365152,
#                                     'recall': 0.8774713512152121,
#                                     'total_fn': 1946,
#                                     'total_fp': 1951,
#                                     'total_obs': 15882,
#                                     'total_tn': 1888607,
#                                     'total_tp': 13936},
#                        'condcols': {   'accuracy': 0.9956318420602541,
#                                        'f1': 0.7853010590529937,
#                                        'precision': 0.7960103440569836,
#                                        'recall': 0.7751544269045985,
#                                        'total_fn': 4914,
#                                        'total_fp': 4361,
#                                        'total_obs': 21855,
#                                        'total_tn': 23168804,
#                                        'total_tp': 16941},
#                        'condops': {   'accuracy': 0.9951396789298224,
#                                       'f1': 0.9291479848331787,
#                                       'precision': 0.9423505612057429,
#                                       'recall': 0.9164493250972318,
#                                       'total_fn': 1826,
#                                       'total_fp': 1249,
#                                       'total_obs': 21855,
#                                       'total_tn': 1247856,
#                                       'total_tp': 20029},
#                        'condval': {   'accuracy': 0.9958691399315698,
#                                       'f1': 0.8721156702208069,
#                                       'precision': 0.8635517073932244,
#                                       'recall': 0.8815171612528441,
#                                       'total_fn': 4895,
#                                       'total_fp': 5749,
#                                       'total_obs': 41314,
#                                       'total_tn': 8214177,
#                                       'total_tp': 36419},
#                        'end': {   'accuracy': 0.983769748851262,
#                                   'f1': 0.9860766499723261,
#                                   'precision': 0.9853450601629525,
#                                   'recall': 0.9868093269568506,
#                                   'total_fn': 2441,
#                                   'total_fp': 2716,
#                                   'total_obs': 185055,
#                                   'total_tn': 129969,
#                                   'total_tp': 182614},
#                        'selcol': {   'accuracy': 0.9986043056280169,
#                                      'f1': 0.8989743692689018,
#                                      'precision': 0.8995423982258235,
#                                      'recall': 0.8987851702649965,
#                                      'total_fn': 1608,
#                                      'total_fp': 1609,
#                                      'total_obs': 15887,
#                                      'total_tn': 23177524,
#                                      'total_tp': 14279},
#                        'start': {   'accuracy': 1.0,
#                                     'f1': 1.0,
#                                     'precision': 1.0,
#                                     'recall': 1.0,
#                                     'total_fn': 0,
#                                     'total_fp': 0,
#                                     'total_obs': 15887,
#                                     'total_tn': 301853,
#                                     'total_tp': 15887}},
#     'train_report': {   'aggop': {   'accuracy': 0.9974287516592061,
#                                      'f1': 0.9037049381079446,
#                                      'precision': 0.9060634450126764,
#                                      'recall': 0.9090473571213116,
#                                      'total_fn': 5126,
#                                      'total_fp': 5133,
#                                      'total_obs': 56359,
#                                      'total_tn': 6702188,
#                                      'total_tp': 51233},
#                         'condcols': {   'accuracy': 0.9990804721059873,
#                                         'f1': 0.9504517229545837,
#                                         'precision': 0.9508923632860203,
#                                         'recall': 0.9501029476921473,
#                                         'total_fn': 3829,
#                                         'total_fp': 3808,
#                                         'total_obs': 76738,
#                                         'total_tn': 82210894,
#                                         'total_tp': 72909},
#                         'condops': {   'accuracy': 0.9986749983786873,
#                                        'f1': 0.9768235742882977,
#                                        'precision': 0.9774235503988029,
#                                        'recall': 0.976269905392374,
#                                        'total_fn': 1821,
#                                        'total_fp': 1750,
#                                        'total_obs': 76738,
#                                        'total_tn': 4430632,
#                                        'total_tp': 74917},
#                         'condval': {   'accuracy': 0.9994734325917023,
#                                        'f1': 0.9816439591078102,
#                                        'precision': 0.9818430201920834,
#                                        'recall': 0.9814785819600474,
#                                        'total_fn': 2839,
#                                        'total_fp': 2779,
#                                        'total_obs': 153282,
#                                        'total_tn': 29153219,
#                                        'total_tp': 150443},
#                         'end': {   'accuracy': 0.9984183166560215,
#                                    'f1': 0.9986316287915126,
#                                    'precision': 0.9985174476157149,
#                                    'recall': 0.9987458360836928,
#                                    'total_fn': 817,
#                                    'total_fp': 966,
#                                    'total_obs': 651430,
#                                    'total_tn': 474884,
#                                    'total_tp': 650613},
#                         'selcol': {   'accuracy': 0.9995939999060015,
#                                       'f1': 0.9680640217290144,
#                                       'precision': 0.9682376605162851,
#                                       'recall': 0.9679760130579803,
#                                       'total_fn': 1805,
#                                       'total_fp': 1806,
#                                       'total_obs': 56364,
#                                       'total_tn': 82233270,
#                                       'total_tp': 54559},
#                         'start': {   'accuracy': 1.0,
#                                      'f1': 1.0,
#                                      'precision': 1.0,
#                                      'recall': 1.0,
#                                      'total_fn': 0,
#                                      'total_fp': 0,
#                                      'total_obs': 56364,
#                                      'total_tn': 1070916,
#                                      'total_tp': 56364}}}
#  Loss: 0.25105445663134257, batch: 225
